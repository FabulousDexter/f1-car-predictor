# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_info_rows', 500)

# %%
# Run data collection script to fetch latest data
import sys
sys.path.append('src')  # Add src folder to path

start_year = 2023
end_year = 2025

from data_collection import get_all_sessions
get_all_sessions(start_year=start_year, end_year=end_year, retry_failed=False)
print("Data ready!")
# Out:
# C:\Users\trngd\InternalDoc\code_projects\f1-car-predictor\src\data_collection.py:100: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   current_event_schedule["Session5DateUtc"] = pd.to_datetime(
# Loaded 5854 existing results from data/f1_all_session_race_results_2023-2025.csv
# Loaded 128463 existing laps from data/f1_all_session_race_laps_2023-2025.csv
# ...
# [1/67] Loading Bahrain Grand Prix...
# ...
#   Skipping FP1 for Bahrain Grand Prix (already fetched)
#   Skipping FP2 for Bahrain Grand Prix (already fetched)
#   Skipping FP3 for Bahrain Grand Prix (already fetched)
#   Skipping Q for Bahrain Grand Prix (already fetched)
#   Skipping R for Bahrain Grand Prix (already fetched)
# ...
# [2/67] Loading Saudi Arabian Grand Prix...
# ...

# %%
# Load your data
df_laps = pd.read_csv(f"data/f1_all_session_race_laps_{start_year}-{end_year}.csv")
df_races = pd.read_csv(f"data/f1_all_session_race_results_{start_year}-{end_year}.csv")

# Quick data overview
print("=== LAPS DATASET ===")
print(f"Shape: {df_laps.shape}")
print(f"\nMissing values:")
print(df_laps.isnull().sum())
print(f"\nData types:")
print(df_laps.dtypes)
df_laps.head(5)
# Out:
# === LAPS DATASET ===
# Shape: (128463, 9)
#
# Missing values:
# Driver             0
# LapNumber          0
# LapTime        18367
# Compound         593
# TyreLife         617
# Year               0
# EventName          0
# RoundNumber        0
# SessionType        0
# dtype: int64
#
# Data types:
# Driver          object
# LapNumber      float64
# LapTime         object
# Compound        object
# TyreLife       float64
# Year             int64
# EventName       object
# RoundNumber      int64
# SessionType     object
# dtype: object
# === RACES DATASET ===
# Shape: (5854, 15)
#
# Missing values:
# DriverNumber       0
# FullName           0
# Position        3279
# TeamName          25
# GridPosition    4557
# Q1              4591
# Q2              4908
# Q3              5227
# Time            4720
# Status          4556
# Points          4556
# Year               0
# EventName          0
# RoundNumber        0
# SessionType        0
# dtype: int64
#
# Data types:
# ...

# %%
print("=== RACES DATASET ===")
print(f"Shape: {df_races.shape}")
print(f"\nMissing values:")
print(df_races.isnull().sum())
print(f"\nData types:")
print(df_races.dtypes)
df_races.head(5)
